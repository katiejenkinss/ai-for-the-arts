# %% [markdown]
# # Jupyter Notebook File Work
#
# This notebook is to help me further my Github skills and also use Jupyter to help me learnn basic programming concepts. It will be submitted as my portfolio for Artificial Intelligence for the Arts & Humanities A.
#
# I would really like to achieve the following
# - Become less daunted by programming
# - Create a portfolio that I am proud of and that showcases what I have learn in a practical way
# - Gain skills I can apply to future projects

# %% [markdown]
# # Hello, World!
#
# ##### This code is my primary attempt at programming using these tools in my course AI for the Arts and Humanities. The purpose of it, is to help me comprehend how to create and run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Printing
#
# After submitting the following prompt to Copilot -
#
# "Could you suggest a python code for ‘Hello, world!’ to demonstrate the concept of printing to a
# complete beginner in programming? Please explain the code step-by-step highlighting any key aspects."
#
# I learned the following:
# - How strings work and their job within programming
# - The importance of every element being typed correctly to ensure it perfoms how it was intended
# - How crucial simple, step by step instructions and explanations are to understanding new concepts as a beginner

# %% [markdown]
#  # Exploring Concepts and Prompts
#
# After experimenting with a variety of prompts, these are the notes I made -
#
# 1. When I asked the same question twice, I typically found it gave me a repeated answer, however this tended to be for more straightforward prompts
# 2. Slight changes in my wording did give different responses, and experimenting with wording is definitely beneficial for beginners to find the easiest code
# 3. It is interesting to see how different prompts can show multiple ways of doing the same thing. However some of these responses became too complex for myself as a beginner so it is useful to keep note of various responses (to ensure you get the easiest one, as mentioned above)

# %%
print("Hello, world!")
# Out:
# Hello, world!
