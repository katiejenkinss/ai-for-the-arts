# %% [markdown]
# # Jupyter Notebook File Work
#
# This notebook is to help me further my Github skills and also use Jupyter to help me learnn basic programming concepts. It will be submitted as my portfolio for Artificial Intelligence for the Arts & Humanities A.
#
# I would really like to achieve the following
# - Become less daunted by programming
# - Create a portfolio that I am proud of and that showcases what I have learn in a practical way
# - Gain skills I can apply to future projects

# %% [markdown]
# # Hello, World!
#
# ##### This code is my primary attempt at programming using these tools in my course AI for the Arts and Humanities. The purpose of it, is to help me comprehend how to create and run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Printing
#
# After submitting the following prompt to Copilot -
#
# "Could you suggest a python code for ‘Hello, world!’ to demonstrate the concept of printing to a
# complete beginner in programming? Please explain the code step-by-step highlighting any key aspects."
#
# I learned the following:
# - How strings work and their job within programming
# - The importance of every element being typed correctly to ensure it perfoms how it was intended
# - How crucial simple, step by step instructions and explanations are to understanding new concepts as a beginner

# %% [markdown]
#  # Exploring Concepts and Prompts
#
# After experimenting with a variety of prompts, these are the notes I made -
#
# 1. When I asked the same question twice, I typically found it gave me a repeated answer, however this tended to be for more straightforward prompts
# 2. Slight changes in my wording did give different responses, and experimenting with wording is definitely beneficial for beginners to find the easiest code
# 3. It is interesting to see how different prompts can show multiple ways of doing the same thing. However some of these responses became too complex for myself as a beginner so it is useful to keep note of various responses (to ensure you get the easiest one, as mentioned above)

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Working on Algorithms, Code and Pseudocode
#
# If we view algortihms as step-by-step procedures, we can think of everday tasks in a similar manner to help us understand the distinction between algortihms, code and pseudocode.
#
# For example, we can think of washing our hands as an algorithm -
# 1. Turn on the tap
# 2. Wet your hands
# 3. Apply hand soap/ hand wash
# 4. Rub hands together, lathering soap and scrubbing in circular motions
# 5. Rinse hands with water
# 6. Turn off tap
# 7. Dry hands
#
# Or making a bowl of cereal -
# 1. Get a bowl
# 2. Get your chosen cereal
# 3. Pour the cereal into the bowl
# 4. Take milk out of the fridge and pour over the cereal
# 5. Get a spoon
# 6. Enjoy your cereal!
#
#
#
# ### Turning my everday algorithms into pseudocode with the help of CoPilot
#
# After trying to write my own pseudo code using the algorithms above, Microsoft Copilot gave me improvements and this was the response -
#
# INPUT: water, soap, towel
# PRECONDITION: Remove jewelry/watches; ensure water and soap are available
#
# TURN ON tap
# WET hands with water
# APPLY soap to hands
# SET timer to 20 seconds
# WHILE timer not expired:
#     RUB hands together
#     SCRUB between fingers, under nails, and wrists
# END WHILE
# RINSE hands thoroughly with water
# TURN OFF tap
# DRY hands completely using towel
# POSTCONDITION: Hands are clean and dry
# OUTPUT: clean hands
#
#
#
# ### Turning my pseudo code into python code
#
# With the help of copilot, I turned my pseudo code into python code, which can be seen below.

# %%
import time

def wash_hands():
    # Preconditions
    water_available = True
    soap_available = True
    towel_available = True

    if not water_available or not soap_available:
        print("Cannot wash hands properly. Please ensure water and soap are available.")
        return

    print("Step 1: Turn on tap.")
    print("Step 2: Wet hands with water.")
    print("Step 3: Apply soap to hands.")

    print("Step 4: Rub hands together for 20 seconds.")
    start_time = time.time()
    while time.time() - start_time < 20:
        # Simulate scrubbing details
        print("...scrubbing between fingers, under nails, and wrists...")
        time.sleep(5)  # Pause to simulate time passing

    print("Step 5: Rinse hands thoroughly with water.")
    print("Step 6: Turn off tap.")

    if towel_available:
        print("Step 7: Dry hands completely using towel.")
    else:
        print("No towel available. Air dry your hands.")

    print("✅ Hands are clean and dry!")

# Run the function
wash_hands()
# Out:
# Step 1: Turn on tap.
# Step 2: Wet hands with water.
# Step 3: Apply soap to hands.
# Step 4: Rub hands together for 20 seconds.
# ...scrubbing between fingers, under nails, and wrists...
# ...scrubbing between fingers, under nails, and wrists...
# ...scrubbing between fingers, under nails, and wrists...
# ...scrubbing between fingers, under nails, and wrists...
# Step 5: Rinse hands thoroughly with water.
# Step 6: Turn off tap.
# Step 7: Dry hands completely using towel.
# ✅ Hands are clean and dry!

# %% [markdown]
# ***Notes on the above code - it appeared to work as intended and works well from what I can see***.

# %% [markdown]
# # Fun with Youtube

# %% [markdown]
# Below is a youtube video that relates to our above algorithm, pseudocode, and code!

# %%
from IPython.display import display, Markdown


from IPython.display import YouTubeVideo

YouTubeVideo("TGddyTW5eMc", width=640, height=360)

# %% [markdown]
# # Images and Audio
#
# Below I will add an image to my notebook
